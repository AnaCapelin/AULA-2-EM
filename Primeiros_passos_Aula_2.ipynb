# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCapelin/AULA-2-EM/blob/main/Primeiros_passos_Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#código que mostra a mensagem olá mundo,
print("Olá, mundo!")
print("HOJE ESTÁ CHOVENDO")
print("Hoje não é sábado")
# Out:
# Olá, mundo!
# Hoje está chovendo
# Hoje não é sábado

# %% [markdown]
# Código para exibir uma mensagem

# %% [markdown]
# Código para fazer uma soma

# %%
print(100 + 27)

print(10 * 2)

print(20 / 5)

print(8 - 3)
# Out:
# 127
# 20
# 4.0
# 5

# %% [markdown]
# fluxograma

# %%
#criação das 2 listas
aprovados = []
recuperacao = []

for contador in range(15):
  nota = float(input(f"Digite a nota do aluno {contador+1}:"))
  if (nota>= 7):
    aprovados.append(f"Aluno {contador+1} Nota{nota}")
  else:
    recuperacao.append(f"Aluno {contador+1} N1
    ota{nota}")

print ("ALUNOS APROVADOS:")
print (aprovados)

print ("ALUNOS EM RECUPERAÇÃO:")
print (recuperacao)
# Out:
# Digite a nota do aluno 1:5
# Digite a nota do aluno 2:6
# Digite a nota do aluno 3:4
# Digite a nota do aluno 4:1
# Digite a nota do aluno 5:2
# Digite a nota do aluno 6:1
# Digite a nota do aluno 7:7
# Digite a nota do aluno 8:8
# Digite a nota do aluno 9:10
# Digite a nota do aluno 10:1
# Digite a nota do aluno 11:12
# Digite a nota do aluno 12:10
# Digite a nota do aluno 13:9
# Digite a nota do aluno 14:6
# Digite a nota do aluno 15:8
# ALUNOS APROVADOS:
# ['Aluno 7 nota7.0', 'Aluno 8 nota8.0', 'Aluno 9 nota10.0', 'Aluno 11 nota12.0', 'Aluno 12 nota10.0', 'Aluno 13 nota9.0', 'Aluno 15 nota8.0']
# ALUNOS EM RECUPERAÇÃO:
# ['Aluno 1 nota5.0', 'Aluno 2 nota6.0', 'Aluno 3 nota4.0', 'Aluno 4 nota1.0', 'Aluno 5 nota2.0', 'Aluno 6 nota1.0', 'Aluno 10 nota1.0', 'Aluno 14 nota6.0']

# %% [markdown]
# Desafio: criar um algoritmo que gere a tabuada do número 10.

# %%
numero = int(input("Digite qual tabuada você deseja:"))
print("tabuada:")
for contador in range(1,11):
  print(f"{numero} x {contador} = {numero*contador}")
# Out:
# Digite qual tabuada você deseja:7
# tabuada:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %% [markdown]
# # Nova seção
